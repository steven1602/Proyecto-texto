# %% [markdown]
# # 1. Unión del Corpus
# Une las reseñas de Google Maps con el dataset IMDB en español.
# Toda la lógica vive en `data/union_corpus.py`.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('.'))

from union_corpus import unir_corpus

# %%
#  unir los datis
corpus = unir_corpus(
    path_cr   = 'Outscraper-20260607153436s0a.csv',
    path_imdb = 'IMDB Dataset SPANISH.csv',   # ajustar si el nombre cambia
    output    = 'corpus_unificado_resenas.csv',
    limite_imdb = 1000,
)
corpus.head()

# %%
print('Forma del corpus:', corpus.shape)
corpus['polaridad'].value_counts()
