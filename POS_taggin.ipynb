# %%
# !pip install nltk spacy pandas
# !python -m spacy download es_core_news_md
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.9.4)
# Requirement already satisfied: spacy in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.8.14)
# Requirement already satisfied: pandas in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (2.2.3)
# Requirement already satisfied: click in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (0.26.3)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: anyio in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: six>=1.5 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\steven16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jinja2->spacy) (3.0.3)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\steven16\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting es-core-news-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.8.0/es_core_news_md-3.8.0-py3-none-any.whl (42.3 MB)
#      ---------------------------------------- 0.0/42.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/42.3 MB ? eta -:--:--
#      ---------------------------------------- 0.3/42.3 MB ? eta -:--:--
#      -- ------------------------------------- 3.1/42.3 MB 12.6 MB/s eta 0:00:04
#      ------- -------------------------------- 7.6/42.3 MB 16.6 MB/s eta 0:00:03
#      ---------- ---------------------------- 11.5/42.3 MB 17.5 MB/s eta 0:00:02
#      ------------ -------------------------- 13.9/42.3 MB 16.2 MB/s eta 0:00:02
#      -------------- ------------------------ 16.0/42.3 MB 15.0 MB/s eta 0:00:02
#      ---------------- ---------------------- 18.1/42.3 MB 14.1 MB/s eta 0:00:02
#      ------------------- ------------------- 20.7/42.3 MB 14.1 MB/s eta 0:00:02
#      --------------------- ----------------- 23.3/42.3 MB 13.8 MB/s eta 0:00:02
#      ----------------------- --------------- 25.2/42.3 MB 13.7 MB/s eta 0:00:02
#      ------------------------ -------------- 26.5/42.3 MB 12.5 MB/s eta 0:00:02
#      -------------------------- ------------ 28.6/42.3 MB 12.4 MB/s eta 0:00:02
#      ---------------------------- ---------- 30.7/42.3 MB 12.0 MB/s eta 0:00:01
#      ------------------------------ -------- 32.8/42.3 MB 11.9 MB/s eta 0:00:01
#      -------------------------------- ------ 35.4/42.3 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 37.7/42.3 MB 12.0 MB/s eta 0:00:01
#      ------------------------------------- - 40.4/42.3 MB 12.0 MB/s eta 0:00:01
#      --------------------------------------  42.2/42.3 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------------- 42.3/42.3 MB 11.4 MB/s  0:00:04
# Installing collected packages: es-core-news-md
# Successfully installed es-core-news-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\steven16\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import pos_tag, pos_tag_sents
import spacy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

print("✓ Librerías importadas correctamente")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 9
#       6 else:
#       7     ssl._create_default_https_context = _create_unverified_https_context
# ----> 9 import nltk
#      10 from nltk.tokenize import word_tokenize, sent_tokenize
#      11 from nltk import pos_tag, pos_tag_sents
#
# File C:\practicaa\.venv\Lib\site-packages\nltk\__init__.py:146
#     140 from nltk.jsontags import *
#     142 ###########################################################
#     143 # PACKAGES
#     144 ###########################################################
# --> 146 from nltk.chunk import *
#     147 from nltk.classify import *
#     148 from nltk.inference import *
#
# File C:\practicaa\.venv\Lib\site-packages\nltk\chunk\__init__.py:155
#       1 # Natural Language Toolkit: Chunkers
#       2 #
#       3 # Copyright (C) 2001-2026 NLTK Project
#    (...)      7 # For license information, see LICENSE.TXT
#       8 #
#      10 """
#      11 Classes and interfaces for identifying non-overlapping linguistic
#      12 groups (such as base noun phrases) in unrestricted text.  This task is
#    (...)    152      pattern is valid.
#     153 """
# --> 155 from nltk.chunk.api import ChunkParserI
#     156 from nltk.chunk.named_entity import Maxent_NE_Chunker
#     157 from nltk.chunk.regexp import RegexpChunkParser, RegexpParser
#
# File C:\practicaa\.venv\Lib\site-packages\nltk\chunk\api.py:13
#       1 # Natural Language Toolkit: Chunk parsing API
#       2 #
#       3 # Copyright (C) 2001-2026 NLTK Project
#    (...)     10 ##  Chunk Parser Interface
#      11 ##//////////////////////////////////////////////////////
# ---> 13 from nltk.chunk.util import ChunkScore
#      14 from nltk.internals import deprecated
#      15 from nltk.parse import ParserI
#
# File C:\practicaa\.venv\Lib\site-packages\nltk\chunk\util.py:12
#       9 import re
#      11 from nltk.metrics import accuracy as _accuracy
# ---> 12 from nltk.tag.mapping import map_tag
#      13 from nltk.tag.util import str2tuple
#      14 from nltk.tree import Tree
#
# File C:\practicaa\.venv\Lib\site-packages\nltk\tag\__init__.py:72
#      70 from nltk.tag.api import TaggerI
#      71 from nltk.tag.util import str2tuple, tuple2str, untag
# ---> 72 from nltk.tag.sequential import (
#      73     SequentialBackoffTagger,
#      74     ContextTagger,
#      75     DefaultTagger,
#      76     NgramTagger,
#      77     UnigramTagger,
#      78     BigramTagger,
#      79     TrigramTagger,
#      80     AffixTagger,
#      81     RegexpTagger,
#      82     ClassifierBasedTagger,
#      83     ClassifierBasedPOSTagger,
#      84 )
#      85 from nltk.tag.brill import BrillTagger
#      86 from nltk.tag.brill_trainer import BrillTaggerTrainer
#
# File C:\practicaa\.venv\Lib\site-packages\nltk\tag\sequential.py:26
#      23 from typing import List, Optional, Tuple
#      25 from nltk import jsontags
# ---> 26 from nltk.classify import NaiveBayesClassifier
#      27 from nltk.probability import ConditionalFreqDist
#      28 from nltk.tag.api import FeaturesetTaggerI, TaggerI
#
# File C:\practicaa\.venv\Lib\site-packages\nltk\classify\__init__.py:97
#      95 from nltk.classify.positivenaivebayes import PositiveNaiveBayesClassifier
#      96 from nltk.classify.rte_classify import RTEFeatureExtractor, rte_classifier, rte_features
# ---> 97 from nltk.classify.scikitlearn import SklearnClassifier
#      98 from nltk.classify.senna import Senna
#      99 from nltk.classify.textcat import TextCat
#
# File C:\practicaa\.venv\Lib\site-packages\nltk\classify\scikitlearn.py:38
#      35 from nltk.probability import DictionaryProbDist
#      37 try:
# ---> 38     from sklearn.feature_extraction import DictVectorizer
#      39     from sklearn.preprocessing import LabelEncoder
#      40 except ImportError:
#
# File C:\practicaa\.venv\Lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)    114     "compose",
#     115 ]
#
# File C:\practicaa\.venv\Lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      20 from .utils._missing import is_scalar_nan
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File C:\practicaa\.venv\Lib\site-packages\sklearn\utils\__init__.py:9
#       7 from . import metadata_routing
#       8 from ._bunch import Bunch
# ----> 9 from ._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from ._indexing import (
#      17     _safe_indexing,  # noqa: F401
#      18     resample,
#      19     shuffle,
#      20 )
#
# File C:\practicaa\.venv\Lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File C:\practicaa\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
# ---> 17 from .validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File C:\practicaa\.venv\Lib\site-packages\sklearn\utils\validation.py:21
#      19 from .. import get_config as _get_config
#      20 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 21 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      22 from ..utils.deprecation import _deprecate_force_all_finite
#      23 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#
# File C:\practicaa\.venv\Lib\site-packages\sklearn\utils\_array_api.py:20
#      18 from ..externals import array_api_extra as xpx
#      19 from ..externals.array_api_compat import numpy as np_compat
# ---> 20 from .fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File C:\practicaa\.venv\Lib\site-packages\sklearn\utils\fixes.py:20
#      17 from scipy import optimize
#      19 try:
# ---> 20     import pandas as pd
#      21 except ImportError:
#      22     pd = None
#
# File C:\practicaa\.venv\Lib\site-packages\pandas\__init__.py:61
#      58 # let init-time option registration happen
#      59 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 61 from pandas.core.api import (
#      62     # dtype
#      63     ArrowDtype,
#      64     Int8Dtype,
#      65     Int16Dtype,
#      66     Int32Dtype,
#      67     Int64Dtype,
#      68     UInt8Dtype,
#      69     UInt16Dtype,
#      70     UInt32Dtype,
#      71     UInt64Dtype,
#      72     Float32Dtype,
#      73     Float64Dtype,
#      74     CategoricalDtype,
#      75     PeriodDtype,
#      76     IntervalDtype,
#      77     DatetimeTZDtype,
#      78     StringDtype,
#      79     BooleanDtype,
#      80     # missing
#      81     NA,
#      82     isna,
#      83     isnull,
#      84     notna,
#      85     notnull,
#      86     # indexes
#      87     Index,
#      88     CategoricalIndex,
#      89     RangeIndex,
#      90     MultiIndex,
#      91     IntervalIndex,
#      92     TimedeltaIndex,
#      93     DatetimeIndex,
#      94     PeriodIndex,
#      95     IndexSlice,
#      96     # tseries
#      97     NaT,
#      98     Period,
#      99     period_range,
#     100     Timedelta,
#     101     timedelta_range,
#     102     Timestamp,
#     103     date_range,
#     104     bdate_range,
#     105     Interval,
#     106     interval_range,
#     107     DateOffset,
#     108     # conversion
#     109     to_numeric,
#     110     to_datetime,
#     111     to_timedelta,
#     112     # misc
#     113     Flags,
#     114     Grouper,
#     115     factorize,
#     116     unique,
#     117     value_counts,
#     118     NamedAgg,
#     119     array,
#     120     Categorical,
#     121     set_eng_float_format,
#     122     Series,
#     123     DataFrame,
#     124 )
#     126 from pandas.core.dtypes.dtypes import SparseDtype
#     128 from pandas.tseries.api import infer_freq
#
# File C:\practicaa\.venv\Lib\site-packages\pandas\core\api.py:28
#      16 from pandas.core.dtypes.missing import (
#      17     isna,
#      18     isnull,
#      19     notna,
#      20     notnull,
#      21 )
#      23 from pandas.core.algorithms import (
#      24     factorize,
#      25     unique,
#      26     value_counts,
#      27 )
# ---> 28 from pandas.core.arrays import Categorical
#      29 from pandas.core.arrays.boolean import BooleanDtype
#      30 from pandas.core.arrays.floating import (
#      31     Float32Dtype,
#      32     Float64Dtype,
#      33 )
#
# File C:\practicaa\.venv\Lib\site-packages\pandas\core\arrays\__init__.py:9
#       7 from pandas.core.arrays.boolean import BooleanArray
#       8 from pandas.core.arrays.categorical import Categorical
# ----> 9 from pandas.core.arrays.datetimes import DatetimeArray
#      10 from pandas.core.arrays.floating import FloatingArray
#      11 from pandas.core.arrays.integer import IntegerArray
#
# File C:\practicaa\.venv\Lib\site-packages\pandas\core\arrays\datetimes.py:19
#      15 import numpy as np
#      17 from pandas._config import using_string_dtype
# ---> 19 from pandas._libs import (
#      20     lib,
#      21     tslib,
#      22 )
#      23 from pandas._libs.tslibs import (
#      24     BaseOffset,
#      25     NaT,
#    (...)     42     tzconversion,
#      43 )
#      44 from pandas._libs.tslibs.dtypes import abbrev_to_npy_unit
#
# File pandas/_libs/tslib.pyx:61, in init pandas._libs.tslib()
#
# AttributeError: partially initialized module 'pandas' from 'C:\practicaa\.venv\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
